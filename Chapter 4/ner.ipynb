# %% [markdown]
# ### Named Entity Recognition with spaCy

# %%
import spacy
from spacy import displacy

# Load English model with NER support
nlp = spacy.load("en_core_web_sm")

# Sample text
text = "Apple was founded by Steve Jobs and Steve Wozniak in California in 1976."

# Process the text
doc = nlp(text)

# Print named entities
print("Named Entities:")
for ent in doc.ents:
    print(f"- {ent.text} ({ent.label_})")
displacy.render(doc, style="ent", jupyter=True)
# Out:
# Named Entities:
# - Apple (ORG)
# - Steve Jobs (PERSON)
# - Steve Wozniak (PERSON)
# - California (GPE)
# - 1976 (DATE)
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Apple
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  was founded by
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Steve Jobs
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  and
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
# ...

# %% [markdown]
# ### NER - challenging cases

# %%
import spacy
nlp = spacy.load("en_core_web_lg")

# Sample text
text = "The patient exhibited signs of tachycardia and was administered 5mg of lorazepam. " \
        "University of California, Berkeley. " \
        "Apple is looking to acquire a London-based AI startup. " \
        "Just had 🍜 in Shinjuku 🇯🇵 — best ramen spot ever! 店員さんも優しかった 😊. " \
        "According to clause 5.3.1 of the LCA Act 2021… " \

# Process the text
doc = nlp(text)

# Print named entities
print("Named Entities:")
for ent in doc.ents:
    print(f"- {ent.text} ({ent.label_})")
# Out:
# Named Entities:
# - 5mg (QUANTITY)
# - University of California, Berkeley (ORG)
# - Apple (ORG)
# - London (GPE)
# - AI (ORG)
# - Shinjuku 🇯 (GPE)
# - 5.3.1 (CARDINAL)
# - the LCA Act (LAW)
# - 2021 (DATE)

# %%
displacy.render(doc, style="ent", jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">The patient exhibited signs of tachycardia and was administered
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     5mg
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#  of lorazepam.
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     University of California, Berkeley
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# .
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Apple
# ...

# %%
# !pip install -U spacy
# !python -m spacy download en_core_web_lg
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 400.7/400.7 MB 3.8 MB/s eta 0:00:00
# ...
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_lg')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.
